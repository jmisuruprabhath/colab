# %%
import requests
import lxml
from bs4 import BeautifulSoup
from xlwt import *

workbook = Workbook(encoding = 'utf-8')
table = workbook.add_sheet('data')
table.write(0, 0, 'Number')
table.write(0, 1, 'Product Name')
table.write(0, 2, 'New Price')
table.write(0, 3, 'Old Price')
table.write(0, 4, 'discount')
line = 1

url = "https://odel.lk/deal-products"
headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36 QIHU 360SE'
}
f = requests.get(url, headers = headers)
products_lst = []
soup = BeautifulSoup(f.content, 'lxml')
products = soup.find_all('div', {'class': 'block2'})
#print(products)

num = 0
for product in products:
    product_cod = product.find('a')['href']
    product_code = product_cod.split("/")
    
    product_name = product.find('a', {'class': 'stext-104'})
    new_price = product.find('span', {'class': 'stext-105'})
    old_price = product.find('del')
    discount = product.find('div', {'class': 'product_tag_discount'})
    print(num, '\n', 'Product: ' + product_name.string.strip())
    print('\n', product_code[len(product_code)-1])
    print('\n', new_price.string.strip())
    print('\n', old_price.string.strip())
    print('\n', discount.string.strip())
    num += 1
    table.write(line, 0, num)
    table.write(line, 1, product_name.string.strip())
    table.write(line, 2, new_price.string.strip())
    table.write(line, 3, old_price.string.strip())
    table.write(line, 4, discount.string.strip())
    line += 1
    workbook.save('Odel_Products.xls')
# Out:
# 0
#  Product: Odel Solid Colour Halter Neck Dress
#
#  34755
#
#  LKR 1,495
#
#  LKR 2,990
#
#  50%
# 1
#  Product: Odel Blue One Shoulder Maxi Dress
#
#  50943
#
#  LKR 2,145
#
#  LKR 4,290
#
#  50%
# 2
#  Product: Tara Navy   Side Tie Up Mini Dress
#
#  51607
#
#  LKR 1,395
#
#  LKR 2,790
#
#  50%
# 3
#  Product: Tara Black Shift  Mini Dress
#
#  51610
#
#  LKR 2,975
#
#  LKR 5,950
#
#  50%
# 4
#  Product: Closet Two Toned Mini Dress
#
#  52496
#
#  LKR 1,975
#
#  LKR 3,950
#
#  50%
# 5
#  Product: Closet Printed Mini Dress
#
#  52499
#
#  LKR 1,745
#
#  LKR 3,490
#
#  50%
# 6
#  Product: Odel  Printed Tie Up Shirt Dress
#
#  53152
#
#  LKR 3,375
#
#  LKR 6,750
#
#  50%
# 7
#  Product: Odel Solid Colour  Button Down  Dress
#
#  53153
#
#  LKR 3,250
#
#  LKR 6,500
#
#  50%
# 8
#  Product: Odel Polka Dot Tie Up Dress
#
#  59285
#
#  LKR 2,395
#
#  LKR 4,790
#
#  50%
# 9
#  Product: Tara Blue Shift Knee Length Dress
#
#  61965
#
#  LKR 3,495
#
#  LKR 6,990
#
#  50%
# 10
#  Product: Tara Solid Colour Dropped Waist Asymmetric Maxi  Dress
#
#  63874
#
#  LKR 2,745
#
#  LKR 5,490
#
#  50%
# 11
#  Product: Tara Solid Colour Dropped Waist Asymmetric Maxi  Dress
#
#  63884
#
#  LKR 2,745
#
#  LKR 5,490
#
#  50%
# 12
#  Product: Odel Red Checked Tie Waist Dress
#
#  63894
#
#  LKR 2,675
#
#  LKR 5,350
#
#  50%
# 13
#  Product: Odel Black Checked Tie Waist Dress
#
#  63895
#
#  LKR 2,675
#
#  LKR 5,350
#
#  50%
# 14
#  Product: Odel Black Stripe Low Waist Dress
#
#  63900
#
#  LKR 2,645
#
#  LKR 5,290
#
#  50%
# 15
#  Product: Odel Pink Halter Shift Dress
#
#  63907
#
#  LKR 2,975
#
#  LKR 5,950
#
#  50%
# 16
#  Product: Closet Check V Neck Bodycon Mini Dress
#
#  64036
#
#  LKR 2,225
#
#  LKR 4,450
#
#  50%
# 17
#  Product: Odel Printed Flounce Hem Wrap Dress
#
#  69414
#
#  LKR 2,895
#
#  LKR 5,790
#
#  50%
# 18
#  Product: Odel Printed Flounce Hem Wrap Dress
#
#  69415
#
#  LKR 2,895
#
#  LKR 5,790
#
#  50%
# 19
#  Product: Odel Embroidery  Knot Detail Puff Sleeve Dress
#
#  69418
#
#  LKR 3,145
#
#  LKR 6,290
#
#  50%
# 20
#  Product: Odel Printed Sholuder Belted Dress
#
#  69422
#
#  LKR 3,145
#
#  LKR 6,290
#
#  50%
# 21
#  Product: Odel Blue Smocked Waist Midi Dress
#
#  69423
#
#  LKR 2,645
#
#  LKR 5,290
#
#  50%
# 22
#  Product: Odel Green Button Down Mini Dress
#
#  69424
#
#  LKR 3,145
#
#  LKR 6,290
#
#  50%
# 23
#  Product: Odel Yellow Ruffle Sleeve Midi Dress
#
#  69425
#
#  LKR 2,145
#
#  LKR 4,290
#
#  50%
# 24
#  Product: Odel Maroon Asymmetric Hem Knit Dress
#
#  69427
#
#  LKR 1,745
#
#  LKR 3,490
#
#  50%
# 25
#  Product: Odel Brown Side Button Detail Mini Dress
#
#  69428
#
#  LKR 2,645
#
#  LKR 5,290
#
#  50%
# 26
#  Product: Biconic Polka Dot Mesh Dress
#
#  69771
#
#  LKR 2,895
#
#  LKR 5,790
#
#  50%
# 27
#  Product: Biconic Floral Print Ruffle Dress
#
#  69776
#
#  LKR 1,995
#
#  LKR 3,990
#
#  50%
# 28
#  Product: Biconic Printed Strapless Dress
#
#  69777
#
#  LKR 1,975
#
#  LKR 3,950
#
#  50%
# 29
#  Product: Tara Navy Blue Shift Long Sleeve Mini Dress
#
#  70037
#
#  LKR 1,745
#
#  LKR 3,490
#
#  50%
# 30
#  Product: Tara Printed Bodycon Knee Lenght Skirt
#
#  70040
#
#  LKR 2,245
#
#  LKR 4,490
#
#  50%
# 31
#  Product: Closet Solid Colour Flutter Sleeve Mini Dress
#
#  70047
#
#  LKR 1,995
#
#  LKR 3,990
#
#  50%
# 32
#  Product: Closet Solid Colour Flutter Sleeve Mini Dress
#
#  70048
#
#  LKR 1,995
#
#  LKR 3,990
#
#  50%
# 33
#  Product: Batman Printed Sleeveless Mini Dress
#
#  70827
#
#  LKR 2,475
#
#  LKR 4,950
#
#  50%
# 34
#  Product: Closet Check Flutter Sleeve Mini Dress
#
#  73619
#
#  LKR 1,995
#
#  LKR 3,990
#
#  50%
# 35
#  Product: Closet Solid Colour Bodycon Mini Dress With Belt
#
#  73625
#
#  LKR 1,745
#
#  LKR 3,490
#
#  50%
# 36
#  Product: Odel Blue Square Neck Skater Mini Dress
#
#  73764
#
#  LKR 1,995
#
#  LKR 3,990
#
#  50%
# 37
#  Product: Odel White Belted Knee Length Dress
#
#  73765
#
#  LKR 2,895
#
#  LKR 5,790
#
#  50%
# 38
#  Product: Odel Printed Halter Neck Maxi Dress
#
#  73768
#
#  LKR 1,975
#
#  LKR 3,950
#
#  50%
# 39
#  Product: Tara Printed Flutter Sleeve Knee Length Dress
#
#  73832
#
#  LKR 3,745
#
#  LKR 7,490
#
#  50%
